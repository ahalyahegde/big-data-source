# %%
csv_records = spark.read.format('csv').load('dbfs:/FileStore/raw_dnb_flat_test_samples.csv', header=True, inferSchema=True)
#csv_records.show(10)
csv_records.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transactionDetail_transactionID</th><th>transactionDetail_transactionTimestamp</th><th>transactionDetail_inLanguage</th><th>transactionDetail_productID</th><th>transactionDetail_productVersion</th><th>inquiryDetail_productVersion</th><th>inquiryDetail_productID</th><th>inquiryDetail_duns</th><th>organization_duns</th><th>organization_dunsControlStatus_operatingStatus_description</th><th>organization_dunsControlStatus_operatingStatus_dnbCode</th><th>organization_dunsControlStatus_isMarketable</th><th>organization_dunsControlStatus_isMailUndeliverable</th><th>organization_dunsControlStatus_isTelephoneDisconnected</th><th>organization_dunsControlStatus_isDelisted</th><th>organization_dunsControlStatus_subjectHandlingDetails</th><th>organization_dunsControlStatus_fullReportDate</th><th>organization_primaryName</th><th>organization_tradeStyleNames_0_name</th><th>organization_tradeStyleNames_0_priority</th><th>organization_websiteAddress_0_url</th><th>organization_websiteAddress_0_domainName</th><th>organization_telephone_0_telephoneNumber</th><th>organization_telephone_0_isdCode</th><th>organization_telephone_0_isUnreachable</th><th>organization_fax_0_faxNumber</th><th>organization_fax_0_isdCode</th><th>organization_primaryAddress_language_description</th><th>organization_primaryAddress_language_dnbCode</th><th>organization_primaryAddress_addressCountry_name</th><th>organization_primaryAddress_addressCountry_isoAlpha2Code</th><th>organization_primaryAddress_addressCountry_fipsCode</th><th>organization_primaryAddress_continentalRegion_name</th><th>organization_primaryAddress_addressLocality_name</th><th>organization_primaryAddress_minorTownName</th><th>organization_primaryAddress_addressRegion_name</th><th>organization_primaryAddress_addressRegion_abbreviatedName</th><th>organization_primaryAddress_addressRegion_fipsCode</th><th>organization_primaryAddress_addressCounty</th><th>organization_primaryAddress_postalCode</th><th>organization_primaryAddress_postalCodePosition</th><th>organization_primaryAddress_streetNumber</th><th>organization_primaryAddress_streetName</th><th>organization_primaryAddress_streetAddress_line1</th><th>organization_primaryAddress_streetAddress_line2</th><th>organization_primaryAddress_postOfficeBox</th><th>organization_primaryAddress_latitude</th><th>organization_primaryAddress_longitude</th><th>organization_primaryAddress_geographicalPrecision_description</th><th>organization_primaryAddress_geographicalPrecision_dnbCode</th><th>organization_primaryAddress_isRegisteredAddress</th><th>organization_primaryAddress_isResidentialAddress</th><th>organization_primaryAddress_statisticalArea</th><th>organization_primaryAddress_locationOwnership</th><th>organization_primaryAddress_premisesArea</th><th>organization_primaryAddress_isManufacturingLocation</th><th>organization_registeredAddress</th><th>organization_mailingAddress</th><th>organization_stockExchanges</th><th>organization_thirdPartyAssessment</th><th>organization_registrationNumbers_0_registrationNumber</th><th>organization_registrationNumbers_0_typeDescription</th><th>organization_registrationNumbers_0_typeDnBCode</th><th>organization_registrationNumbers_1_registrationNumber</th><th>organization_registrationNumbers_1_typeDescription</th><th>organization_registrationNumbers_1_typeDnBCode</th><th>organization_registrationNumbers_2_registrationNumber</th><th>organization_registrationNumbers_2_typeDescription</th><th>organization_registrationNumbers_2_typeDnBCode</th><th>organization_industryCodes_0_code</th><th>organization_industryCodes_0_description</th><th>organization_industryCodes_0_typeDescription</th><th>organization_industryCodes_0_typeDnBCode</th><th>organization_industryCodes_0_priority</th><th>organization_industryCodes_1_code</th><th>organization_industryCodes_1_description</th><th>organization_industryCodes_1_typeDescription</th>< ...

# %%
subset = csv_records.select('transactionDetail_transactionID', 'transactionDetail_transactionTimestamp', 'organization_telephone_0_isdCode')
subset.show()


# Using alias as the columns names are long
from pyspark.sql.functions import col
subset = subset.select(col('transactionDetail_transactionID').alias('trans_id'), 
                            col('transactionDetail_transactionTimestamp').alias('trans_stamp'), 
                            col('organization_telephone_0_isdCode').alias('isd_code'))
subset.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------------------+--------------------------------------+--------------------------------+
# transactionDetail_transactionID|transactionDetail_transactionTimestamp|organization_telephone_0_isdCode|
# +-------------------------------+--------------------------------------+--------------------------------+
#            rrt-01cec5575e630...|                  2022-10-04 20:03:...|                              39|
#            rrt-0da49783b2e75...|                  2022-10-04 20:35:...|                              44|
#            rrt-0fd54b004b6ff...|                  2022-10-04 19:38:...|                              44|
#            rrt-0fc5679654dea...|                  2022-10-04 19:39:...|                              49|
#            rrt-0dc6dc3b7bb49...|                  2022-07-19 12:03:...|                              49|
#            rrt-01cec5575e630...|                  2022-09-28 14:58:...|                              39|
#            rrt-0f952ef13aa4a...|                  2022-10-04 19:47:...|                              31|
# +-------------------------------+--------------------------------------+--------------------------------+
#
# +--------------------+--------------------+--------+
#             trans_id|         trans_stamp|isd_code|
# +--------------------+--------------------+--------+
# rrt-01cec5575e630...|2022-10-04 20:03:...|      39|
# rrt-0da49783b2e75...|2022-10-04 20:35:...|      44|
# rrt-0fd54b004b6ff...|2022-10-04 19:38:...|      44|
# rrt-0fc5679654dea...|2022-10-04 19:39:...|      49|
# rrt-0dc6dc3b7bb49...|2022-07-19 12:03:...|      49|
# rrt-01cec5575e630...|2022-09-28 14:58:...|      39|
# rrt-0f952ef13aa4a...|2022-10-04 19:47:...|      31|
# +--------------------+--------------------+--------+
#
# </div>

# %%
from pyspark.sql.functions import date_format

new_column = subset.withColumn('created_year', date_format("trans_stamp", 'yyyy'))
new_column.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------+------------+
#             trans_id|         trans_stamp|isd_code|created_year|
# +--------------------+--------------------+--------+------------+
# rrt-01cec5575e630...|2022-10-04 20:03:...|      39|        2022|
# rrt-0da49783b2e75...|2022-10-04 20:35:...|      44|        2022|
# rrt-0fd54b004b6ff...|2022-10-04 19:38:...|      44|        2022|
# rrt-0fc5679654dea...|2022-10-04 19:39:...|      49|        2022|
# rrt-0dc6dc3b7bb49...|2022-07-19 12:03:...|      49|        2022|
# rrt-01cec5575e630...|2022-09-28 14:58:...|      39|        2022|
# rrt-0f952ef13aa4a...|2022-10-04 19:47:...|      31|        2022|
# +--------------------+--------------------+--------+------------+
#
# </div>

# %%
partiotned_table = new_column.write.format('delta') \
                                   .mode('overwrite') \
                                   .partitionBy('created_year') \
                                   .saveAsTable('pyspark_trial_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /user/hive/warehouse/pyspark_trial_table/created_year=2022/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/pyspark_trial_table/created_year=2022/part-00000-054a860d-c7ec-4679-ad0d-d6950bd270a5.c000.snappy.parquet</td><td>part-00000-054a860d-c7ec-4679-ad0d-d6950bd270a5.c000.snappy.parquet</td><td>1538</td></tr><tr><td>dbfs:/user/hive/warehouse/pyspark_trial_table/created_year=2022/part-00000-137319df-9b04-46e6-a82b-5f4f8090e7df.c000.snappy.parquet</td><td>part-00000-137319df-9b04-46e6-a82b-5f4f8090e7df.c000.snappy.parquet</td><td>1538</td></tr></tbody></table></div>

# %%
# %sql 
select * from pyspark_trial_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trans_id</th><th>trans_stamp</th><th>isd_code</th><th>created_year</th></tr></thead><tbody><tr><td>rrt-01cec5575e630f3f5-b-ea-29736-28890909-144_3249</td><td>2022-10-04T20:03:51.301+0000</td><td>39</td><td>2022</td></tr><tr><td>rrt-0da49783b2e75434a-d-ea-13987-18725638-181_3249</td><td>2022-10-04T20:35:33.990+0000</td><td>44</td><td>2022</td></tr><tr><td>rrt-0fd54b004b6ff9504-b-ea-9216-16494591-118_3249</td><td>2022-10-04T19:38:25.687+0000</td><td>44</td><td>2022</td></tr><tr><td>rrt-0fc5679654dea58b9-d-ea-25562-31636126-118_3249</td><td>2022-10-04T19:39:41.682+0000</td><td>49</td><td>2022</td></tr><tr><td>rrt-0dc6dc3b7bb49b100-c-ea-20072-27724794-432_3249</td><td>2022-07-19T12:03:18.096+0000</td><td>49</td><td>2022</td></tr><tr><td>rrt-01cec5575e630f3f5-b-ea-29736-17221187-14_3249</td><td>2022-09-28T14:58:11.917+0000</td><td>39</td><td>2022</td></tr><tr><td>rrt-0f952ef13aa4af7b7-b-ea-19105-28820478-17_3249</td><td>2022-10-04T19:47:13.815+0000</td><td>31</td><td>2022</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F
updated_df = new_column.withColumn('created_year', F.when(new_column['isd_code'] == '44', '2021')
                                                    .otherwise(new_column['created_year'])
                                  )
updated_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+--------+------------+
#             trans_id|         trans_stamp|isd_code|created_year|
# +--------------------+--------------------+--------+------------+
# rrt-01cec5575e630...|2022-10-04 20:03:...|      39|        2022|
# rrt-0da49783b2e75...|2022-10-04 20:35:...|      44|        2021|
# rrt-0fd54b004b6ff...|2022-10-04 19:38:...|      44|        2021|
# rrt-0fc5679654dea...|2022-10-04 19:39:...|      49|        2022|
# rrt-0dc6dc3b7bb49...|2022-07-19 12:03:...|      49|        2022|
# rrt-01cec5575e630...|2022-09-28 14:58:...|      39|        2022|
# rrt-0f952ef13aa4a...|2022-10-04 19:47:...|      31|        2022|
# +--------------------+--------------------+--------+------------+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
